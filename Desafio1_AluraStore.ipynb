# %% [markdown]
# <a href="https://colab.research.google.com/github/danielli-arcari/Alura_Store/blob/main/Desafio1_AluraStore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #SOBRE ESTE PROJETO:
#
# Este projeto faz parte dos estudos em Data Science da Alura One G9.
#
# **SITUAÇÃO PROBLEMA:** O Sr. João precisa decidir qual loja da sua rede Alura Store vender para iniciar um novo empreendimento. Para isso, eu, na posição de cientista de dados, deverei analisar os dados de vendas, desempenho e avaliações das 4 lojas fictícias da Alura Store.
#
# **OBJETIVO:** identificar a loja com menor eficiência e apresentar uma recomendação final baseada nos dados.
#
# O que será aqui exercitado:
#
# -Carregar e manipular dados CSV com a biblioteca Pandas .
#
# -Criar visualizações de dados com biblioteca Matplotlib.
#
# -Analisar métricas como faturamento, avaliações e desempenho de vendas.
#
# **REQUISITOS:**
#
# -Analisar os dados das lojas:avaliar informações como faturamento, categorias mais vendidas, avaliações dos clientes, produtos mais vendidos e frete médio.
#
# -Criar gráficos para visualização:
#
# -Decidir quais tipos de gráficos usar para apresentar os resultados de maneira clara e visual. A análise deve conter, no mínimo, 3 gráficos diferentes, que podem incluir gráficos de barras, pizza, dispersão, entre outros.
#
# -Apresentar uma recomendação: Após as análises, um texto deve ser apresentado, explicando qual loja o Senhor João deve vender e por quê, com base nos dados apresentados.
#
# Os dados de cada loja estão disponíveis nos arquivos CSV e serão carregados utilizando o código base já fornecido. O código extrai informações das quatro lojas e organiza os dados em DataFrames utilizando a biblioteca Pandas.
#
# **DETALHES IMPORTANTES:**
#
# **Código base:** Ele já está preparado para extrair e organizar os dados corretamente, não é necessário modificar.
#
# **Os dados são armazenados em DataFrames:** Cada loja tem o seu conjunto de dados (loja1, loja2, loja3 e loja4), e você deve utilizá-los para as próximas etapas do desafio.
#
# Base de dados disponível em: https://github.com/alura-es-cursos/challenge1-data-science/tree/main> Nesse link consta o banco de dados das 4 lojas fictícias:
#
# loja1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
#
# loja2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
#
# loja3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
#
# loja4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"
#
# Em 05/02/2026

# %% [markdown]
# #Importando os dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %%
#conferindo a estrutura dos dataframes:
loja.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
loja2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
loja3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
loja4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2358 non-null   object
#  1   Categoria do Produto    2358 non-null   object
#  2   Preço                   2358 non-null   float64
#  3   Frete                   2358 non-null   float64
#  4   Data da Compra          2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Local da compra         2358 non-null   object
#  7   Avaliação da compra     2358 non-null   int64
#  8   Tipo de pagamento       2358 non-null   object
#  9   Quantidade de parcelas  2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB

# %% [markdown]
# #Explorando os dataframes

# %% [markdown]
# ##LOJA1:

# %%
loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %%
loja.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
loja.describe()
# Out:
#              Preço        Frete  Avaliação da compra  Quantidade de parcelas  \
# count  2359.000000  2359.000000          2359.000000             2359.000000
# mean    650.491361    34.691805             3.976685                2.943196
# std     819.582778    43.814183             1.415370                2.819897
# min      10.070000     0.000000             1.000000                1.000000
# 25%      74.345000     4.141783             3.000000                1.000000
# 50%     313.750000    16.498835             5.000000                1.000000
# 75%     904.130000    48.050074             5.000000                4.000000
# max    3969.380000   214.377060             5.000000               24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean    -20.763366   -47.349385
# std       5.372400     4.183180
# min     -30.170000   -70.550000
# 25%     -22.250000   -48.790000
# 50%     -22.190000   -48.790000
# 75%     -18.100000   -44.380000
# ...

# %%
loja['Avaliação da compra'].describe()
# Out:
# count    2359.000000
# mean        3.976685
# std         1.415370
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000
# Name: Avaliação da compra, dtype: float64

# %%
#Vendo datas:
loja['Data da Compra'].min()
# Out:
# '01/01/2020'

# %%
loja['Data da Compra'].max()
# Out:
# '31/12/2022'

# %% [markdown]
# ##LOJA2:

# %%
loja2.head()
# Out:
#                  Produto   Categoria do Produto    Preço      Frete  \
# 0  Cadeira de escritório                 moveis   378.20  20.421138
# 1               Pandeiro  instrumentos musicais   102.37   3.035334
# 2              Cama king                 moveis   591.13  31.759020
# 3              Cama king                 moveis  1208.24  61.919584
# 4  Cadeira de escritório                 moveis   530.41  25.827176
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     04/08/2021    Thiago Silva              MG                    1
# 1     26/11/2020   Bianca Santos              RJ                    3
# 2     22/10/2021    Thiago Silva              SC                    5
# 3     04/05/2022   Larissa Alves              RS                    5
# 4     26/02/2022  Lucas Oliveira              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0            boleto                       1 -18.10 -44.38
# ...

# %%
loja2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
loja2.describe()
# Out:
#              Preço        Frete  Avaliação da compra  Quantidade de parcelas  \
# count  2359.000000  2359.000000          2359.000000             2359.000000
# mean    630.970352    33.621941             4.037304                2.902501
# std     794.078997    42.321932             1.356153                2.848416
# min      10.160000     0.000000             1.000000                1.000000
# 25%      72.730000     3.904020             4.000000                1.000000
# 50%     290.960000    15.406740             5.000000                1.000000
# 75%     903.580000    47.250196             5.000000                4.000000
# max    3937.850000   216.707633             5.000000               24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean    -20.473243   -47.098508
# std       5.321015     4.169111
# min     -30.170000   -70.550000
# 25%     -22.250000   -48.790000
# 50%     -22.190000   -48.790000
# 75%     -18.100000   -44.380000
# ...

# %%
loja2.shape
# Out:
# (2359, 12)

# %%
loja2['Data da Compra'].min()
# Out:
# '01/01/2020'

# %%
loja2['Data da Compra'].max()
# Out:
# '31/12/2022'

# %% [markdown]
# ##LOJA3:

# %%
loja3.head()
# Out:
#               Produto   Categoria do Produto    Preço      Frete  \
# 0  Secadora de roupas       eletrodomesticos  1713.50  88.823159
# 1              Cômoda                 moveis   386.81  18.180908
# 2              Violão  instrumentos musicais   404.62  23.197592
# 3       Bola de vôlei        esporte e lazer    78.40   4.463341
# 4       Guarda roupas                 moveis   694.76  34.578319
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     17/12/2021  Camila Ribeiro              CE                    4
# 1     10/02/2021   Larissa Alves              RS                    3
# 2     22/01/2023  Lucas Oliveira              SP                    5
# 3     22/03/2022     Pedro Gomes              BA                    4
# 4     12/01/2022   Bianca Santos              SP                    1
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       4  -5.20 -39.53
# ...

# %%
loja3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
loja3.describe()
# Out:
#              Preço        Frete  Avaliação da compra  Quantidade de parcelas  \
# count  2359.000000  2359.000000          2359.000000             2359.000000
# mean    620.612560    33.074464             4.048326                2.967783
# std     774.191691    41.260516             1.386426                2.812153
# min      10.080000     0.000000             1.000000                1.000000
# 25%      76.560000     4.149261             4.000000                1.000000
# 50%     301.670000    15.879702             5.000000                2.000000
# 75%     888.040000    46.635503             5.000000                4.000000
# max    3957.620000   211.257624             5.000000               24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean    -20.405396   -47.129233
# std       5.465572     4.197520
# min     -30.170000   -70.550000
# 25%     -22.250000   -48.790000
# 50%     -22.190000   -48.790000
# 75%     -18.100000   -44.380000
# ...

# %%
loja3.shape
# Out:
# (2359, 12)

# %%
loja3['Data da Compra'].min()
# Out:
# '01/01/2020'

# %%
loja3['Data da Compra'].max()
# Out:
# '31/12/2021'

# %% [markdown]
# ##LOJA4:

# %%
loja4.head()
# Out:
#                Produto Categoria do Produto    Preço      Frete  \
# 0          Lava louças     eletrodomesticos  1446.46  74.604083
# 1             Cama box               moveis   631.70  33.919251
# 2     Bola de basquete      esporte e lazer    31.54   0.000000
# 3  Modelagem preditiva               livros    76.93   1.680730
# 4       Fone de ouvido          eletronicos   185.14   7.442587
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     11/11/2022    Rafael Costa              SP                    4
# 1     03/01/2020    Thiago Silva              GO                    5
# 2     25/12/2022   Larissa Alves              MG                    5
# 3     23/11/2021  Lucas Oliveira              MG                    3
# 4     25/04/2022   Bianca Santos              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       3 -22.19 -48.79
# ...

# %%
loja4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2358 non-null   object
#  1   Categoria do Produto    2358 non-null   object
#  2   Preço                   2358 non-null   float64
#  3   Frete                   2358 non-null   float64
#  4   Data da Compra          2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Local da compra         2358 non-null   object
#  7   Avaliação da compra     2358 non-null   int64
#  8   Tipo de pagamento       2358 non-null   object
#  9   Quantidade de parcelas  2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB

# %%
loja4.describe()
# Out:
#              Preço        Frete  Avaliação da compra  Quantidade de parcelas  \
# count  2358.000000  2358.000000          2358.000000             2358.000000
# mean    587.149101    31.278997             3.995759                2.896098
# std     758.341290    40.373136             1.403063                2.730393
# min      10.170000     0.000000             1.000000                1.000000
# 25%      71.225000     3.847061             3.000000                1.000000
# 50%     279.315000    14.614197             5.000000                1.000000
# 75%     845.577500    44.438533             5.000000                4.000000
# max    3869.560000   206.325555             5.000000               18.000000
#
#                lat          lon
# count  2358.000000  2358.000000
# mean    -20.494215   -47.107553
# std       5.433033     4.159156
# min     -30.170000   -65.100000
# 25%     -22.250000   -48.790000
# 50%     -22.190000   -48.790000
# 75%     -18.100000   -44.380000
# ...

# %%
loja4.shape
# Out:
# (2358, 12)

# %%
loja4['Data da Compra'].min()
# Out:
# '01/01/2020'

# %%
loja4['Data da Compra'].max()
# Out:
# '31/12/2022'

# %% [markdown]
# #1. Análise do faturamento

# %%
#O faturamento é o indicador de volume. Precisamos saber qual loja gera mais receita bruta:
import matplotlib.pyplot as plt

# %%
# Calculando o faturamento total de cada loja
faturamento = {
    'Loja 1': loja['Preço'].sum(),
    'Loja 2': loja2['Preço'].sum(),
    'Loja 3': loja3['Preço'].sum(),
    'Loja 4': loja4['Preço'].sum()
}

faturamento_df = pd.DataFrame(list(faturamento.items()), columns=['Loja', 'Faturamento Total'])

faturamento_df
# Out:
#      Loja  Faturamento Total
# 0  Loja 1         1534509.12
# 1  Loja 2         1488459.06
# 2  Loja 3         1464025.03
# 3  Loja 4         1384497.58

# %%
# Gráfico 1: Barras para comparação de Faturamento
# Gráfico 1: Pizza para comparação de Faturamento
plt.figure(figsize=(8, 8))

plt.pie(
    faturamentos,
    labels=nomes_lojas,
    autopct='%1.1f%%',
    startangle=90
)
plt.axis('equal')
plt.title('Participação no Faturamento Total por Loja')
plt.show()

# %% [markdown]
# ####A análise do faturamento total demonstra que a Loja 1 apresenta o maior volume de receita, enquanto a Loja 4 possui o menor faturamento entre as quatro unidades. Observa-se que a Loja 4 apresenta desempenho inferior em comparação às demais, com diferença relevante em relação às outras lojas, indicando menor capacidade de geração de receita no período analisado.

# %% [markdown]
# #2. Vendas por Categoria

# %%
#Isso mostra a diversidade da loja. Uma loja que depende de apenas um produto é mais arriscada.
#Verificando Vendas por Categoria da Loja1:
vendas_categoria_L1 = loja['Categoria do Produto'].value_counts()
vendas_categoria_L1
# Out:
# Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: count, dtype: int64

# %%
#Verificando Vendas por Categoria da Loja2:
vendas_categoria_L2 = loja2['Categoria do Produto'].value_counts()
vendas_categoria_L2
# Out:
# Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: count, dtype: int64

# %%
#Verificando Vendas por Categoria da Loja3:
vendas_categoria_L3 = loja3['Categoria do Produto'].value_counts()
vendas_categoria_L3
# Out:
# Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# livros                   185
# instrumentos musicais    177
# utilidades domesticas    177
# Name: count, dtype: int64

# %%
#Verificando Vendas por Categoria da Loja4:
vendas_categoria_L4 = loja4['Categoria do Produto'].value_counts()
vendas_categoria_L4
# Out:
# Categoria do Produto
# moveis                   480
# eletronicos              451
# brinquedos               338
# esporte e lazer          277
# eletrodomesticos         254
# utilidades domesticas    201
# livros                   187
# instrumentos musicais    170
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Criando um dicionário com as contagens de Vendas por Categoria

df_categorias = pd.DataFrame({
    'Loja 1': loja['Categoria do Produto'].value_counts(),
    'Loja 2': loja2['Categoria do Produto'].value_counts(),
    'Loja 3': loja3['Categoria do Produto'].value_counts(),
    'Loja 4': loja4['Categoria do Produto'].value_counts()
}).fillna(0) # Substitui categorias inexistentes em alguma loja por 0

print(df_categorias)
# Out:
#                        Loja 1  Loja 2  Loja 3  Loja 4
# Categoria do Produto
# brinquedos                324     313     315     338
# eletrodomesticos          312     305     278     254
# eletronicos               448     422     451     451
# esporte e lazer           284     275     277     277
# instrumentos musicais     182     224     177     170
# livros                    173     197     185     187
# moveis                    465     442     499     480
# utilidades domesticas     171     181     177     201

# %%
#Gerando um gráfico de comparação de vendas por categoria das 4 lojas:
# Definindo o estilo e o tamanho
plt.style.use('ggplot')
ax = df_categorias.plot(kind='bar', figsize=(12, 6), width=0.8)

# Personalizando o gráfico
plt.title('Comparativo de Vendas por Categoria entre as Lojas', fontsize=15)
plt.xlabel('Categorias', fontsize=12)
plt.ylabel('Quantidade de Vendas', fontsize=12)
plt.xticks(rotation=45) # Inclina os nomes das categorias para não embolar
plt.legend(title='Lojas')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# ####**Conclusão**: A análise das vendas por categoria demonstra que a Loja 4 não apresenta desempenho inferior generalizado. Em diversas categorias como móveis, eletrônicos e utilidades domésticas, seu volume de vendas é comparável ou superior ao das demais lojas. Isso indica que o menor faturamento total da Loja 4 pode estar relacionado ao ticket médio ou ao mix de produtos vendidos, e não necessariamente à baixa quantidade de vendas.

# %% [markdown]
# #3. Média de Avaliação das Lojas

# %%
avaliacao = {
    'Loja 1': loja['Avaliação da compra'].mean(),
    'Loja 2': loja2['Avaliação da compra'].mean(),
    'Loja 3': loja3['Avaliação da compra'].mean(),
    'Loja 4': loja4['Avaliação da compra'].mean()
}

avaliacao_df = pd.DataFrame(list(avaliacao.items()), columns=['Loja', 'Avaliação Média'])

avaliacao_df
# Out:
#      Loja  Avaliação Média
# 0  Loja 1         3.976685
# 1  Loja 2         4.037304
# 2  Loja 3         4.048326
# 3  Loja 4         3.995759

# %%
plt.figure()
plt.bar(avaliacao_df['Loja'], avaliacao_df['Avaliação Média'])
plt.title('Média de Avaliação por Loja')
plt.xlabel('Loja')
plt.ylabel('Avaliação Média')
plt.show()

# %%
#o gráfico de dispersão ajudará a visualizar melhor se a loja que vende mais é que é a mais bem avaliada:
plt.figure()
plt.scatter(faturamento_df['Faturamento Total'], avaliacao_df['Avaliação Média'])

plt.xlabel('Faturamento Total')
plt.ylabel('Avaliação Média')
plt.title('Relação entre Faturamento e Avaliação')
plt.show()

# %% [markdown]
# ####A média de avaliação das quatro lojas apresenta valores bastante próximos, todos em torno de 4 pontos. A Loja 3 possui a maior média, enquanto a Loja 1 apresenta a menor, porém a diferença entre elas é pequena, não indicando problema significativo de satisfação em nenhuma unidade. Assim, a avaliação dos clientes não se mostra um fator determinante isolado para a decisão de venda.
#
# ####O gráfico de dispersão entre faturamento e avaliação média demonstra que não há correlação direta entre maior receita e melhor satisfação do cliente. A Loja 3 apresenta a melhor avaliação, porém não lidera em faturamento, enquanto a Loja 1 possui maior receita, mas avaliação inferior às demais. Dessa forma, a satisfação dos clientes não se apresenta como fator determinante para explicar o desempenho financeiro das lojas.

# %% [markdown]
# #4. Produtos Mais e Menos Vendidos

# %%
#Top5 de cada loja:
print("Loja 1:")
print(loja['Produto'].value_counts().head())

print("\nLoja 2:")
print(loja2['Produto'].value_counts().head())

print("\nLoja 3:")
print(loja3['Produto'].value_counts().head())

print("\nLoja 4:")
print(loja4['Produto'].value_counts().head())
# Out:
# Loja 1:
# Produto
# Micro-ondas           60
# TV Led UHD 4K         60
# Guarda roupas         60
# Secadora de roupas    58
# Cômoda                56
# Name: count, dtype: int64
#
# Loja 2:
# Produto
# Iniciando em programação    65
# Micro-ondas                 62
# Bateria                     61
# Violão                      58
# Pandeiro                    58
# Name: count, dtype: int64
#
# Loja 3:
# Produto
# Kit banquetas      57
# Mesa de jantar     56
# Cama king          56
# Jogo de panelas    55
# Cômoda             55
# Name: count, dtype: int64
#
# Loja 4:
# Produto
# Cama box                    62
# Faqueiro                    59
# Dashboards com Power BI     56
# Cama king                   56
# Carrinho controle remoto    55
# Name: count, dtype: int64

# %%
#Os menos vendidos (top 5)
print("Loja 1:")
print(loja['Produto'].value_counts().tail())

print("\nLoja 2:")
print(loja2['Produto'].value_counts().tail())

print("\nLoja 3:")
print(loja3['Produto'].value_counts().tail())

print("\nLoja 4:")
print(loja4['Produto'].value_counts().tail())
# Out:
# Loja 1:
# Produto
# Ciência de dados com python    39
# Pandeiro                       36
# Panela de pressão              35
# Headset                        33
# Celular ABXY                   33
# Name: count, dtype: int64
#
# Loja 2:
# Produto
# Fone de ouvido       37
# Poltrona             35
# Mesa de jantar       34
# Impressora           34
# Jogo de tabuleiro    32
# Name: count, dtype: int64
#
# Loja 3:
# Produto
# Guitarra            38
# Jogo de copos       36
# Mochila             36
# Micro-ondas         36
# Blocos de montar    35
# Name: count, dtype: int64
#
# Loja 4:
# Produto
# Geladeira                      38
# Ciência de dados com python    38
# Violão                         37
# Guarda roupas                  34
# Guitarra                       33
# Name: count, dtype: int64

# %% [markdown]
# ####A análise dos produtos mais e menos vendidos demonstra que as quatro lojas possuem portfólios diversificados, sem concentração excessiva em um único item. A Loja 3 apresenta maior especialização em móveis, enquanto as demais mostram maior variedade de categorias. Não foram identificados produtos com desempenho extremamente baixo que indiquem falhas significativas de estoque ou demanda.

# %% [markdown]
# #5. Frete Médio por Loja

# %%
frete = {
    'Loja 1': loja['Frete'].mean(),
    'Loja 2': loja2['Frete'].mean(),
    'Loja 3': loja3['Frete'].mean(),
    'Loja 4': loja4['Frete'].mean()
}

frete_df = pd.DataFrame(list(frete.items()), columns=['Loja', 'Frete Médio'])

frete_df
# Out:
#      Loja  Frete Médio
# 0  Loja 1    34.691805
# 1  Loja 2    33.621941
# 2  Loja 3    33.074464
# 3  Loja 4    31.278997

# %%
plt.figure()
plt.bar(frete_df['Loja'], frete_df['Frete Médio'])
plt.title('Frete Médio por Loja')
plt.xlabel('Loja')
plt.ylabel('Frete Médio')
plt.show()

# %% [markdown]
# ####A análise do frete médio indica que a Loja 4 apresenta o menor custo médio de entrega entre as quatro unidades. Esse resultado sugere eficiência logística, não sendo o frete um fator que explique o menor faturamento observado anteriormente. Dessa forma, o desempenho inferior em receita pode estar relacionado ao ticket médio ou ao mix de produtos comercializados.

# %% [markdown]
# #6. Análise geográfica das vendas

# %%
#Nesta seção, será realizada uma análise exploratória adicional utilizando as coordenadas geográficas das vendas, com o objetivo de identificar possíveis padrões regionais que possam influenciar o desempenho das lojas.
plt.figure()

plt.scatter(loja['lon'], loja['lat'], alpha=0.5, label='Loja 1')
plt.scatter(loja2['lon'], loja2['lat'], alpha=0.5, label='Loja 2')
plt.scatter(loja3['lon'], loja3['lat'], alpha=0.5, label='Loja 3')
plt.scatter(loja4['lon'], loja4['lat'], alpha=0.5, label='Loja 4')

plt.title('Distribuição Geográfica das Vendas')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.show()

# %% [markdown]
# ####A análise geográfica das vendas demonstra que as quatro lojas apresentam distribuição espacial semelhante, atuando em regiões próximas e com padrão de dispersão equivalente. Não foram identificadas concentrações regionais que justifiquem diferenças significativas no desempenho financeiro entre as lojas. Dessa forma, a localização geográfica não se apresenta como fator determinante para o menor faturamento observado na Loja 4.

# %% [markdown]
# #7.Relatório conclusivo

# %% [markdown]
# **Introdução**
#
# O presente relatório tem como objetivo analisar o desempenho das quatro lojas da rede Alura Store, com a finalidade de identificar qual unidade apresenta o menor desempenho comparativo. A análise foi realizada com base nas seguintes métricas: faturamento total, categorias mais populares, média de avaliação dos clientes, produtos mais e menos vendidos e custo médio do frete.
#
# **Análise do Faturamento**
#
# A análise do faturamento total indica que a Loja 4 apresenta a menor receita entre as quatro unidades. Embora a diferença não seja extremamente elevada, a Loja 4 permanece consistentemente abaixo das demais no indicador financeiro mais relevante para o negócio.
#
# **Categorias Mais Vendidas**
#
# A distribuição das categorias de produtos mostra que todas as lojas possuem portfólios diversificados, com destaque para móveis, eletrônicos e eletrodomésticos. A Loja 4 não apresenta concentração excessiva em uma única categoria, porém também não se destaca de forma significativa em relação às demais unidades.
#
# **Média de Avaliação dos Clientes**
#
# As quatro lojas apresentam médias de avaliação próximas a 4 pontos, indicando bom nível de satisfação dos clientes. Não há diferença expressiva entre as unidades que justifique decisão baseada exclusivamente nesse critério.
#
# **Produtos Mais e Menos Vendidos**
#
# A análise dos produtos mais e menos vendidos demonstra que nenhuma loja possui produtos com desempenho extremamente inferior ou dependência crítica de um único item. A Loja 4 apresenta comportamento semelhante às demais nesse aspecto.
#
# **Frete Médio**
#
# A Loja 4 apresenta o menor custo médio de frete, o que indica eficiência logística. No entanto, esse fator positivo não compensa o menor faturamento observado na comparação geral.
#
# **Conclusão**
#
# Com base nas análises realizadas, conclui-se que a Loja 4 apresenta o menor desempenho financeiro entre as unidades da rede Alura Store. Apesar de possuir avaliações satisfatórias e frete competitivo, seu faturamento total é inferior ao das demais lojas.
#
# Dessa forma, recomenda-se que o Sr. João considere a venda da Loja 4 para obter capital e investir em seu novo empreendimento.

# %% [markdown]
# ####**Storytelling Estratégico**
#
# Sr. João,
#
# Fui contratada para analisar o desempenho das quatro lojas da Alura Store com o objetivo de identificar qual unidade apresenta o menor desempenho comparativo e, assim, apoiar sua decisão estratégica de venda.
#
# Iniciei a análise avaliando o faturamento total de cada loja. Observou-se que a Loja 4 apresenta a menor receita entre as quatro unidades. Embora a diferença não seja extremamente elevada, ela permanece consistentemente abaixo das demais no principal indicador financeiro do negócio.
#
# Em seguida, analisei as categorias mais vendidas e o desempenho dos produtos. As quatro lojas possuem portfólios diversificados, sem dependência excessiva de um único produto ou categoria. A Loja 4 não apresenta fragilidades graves nesse aspecto, porém também não demonstra diferencial competitivo relevante.
#
# A média de avaliação dos clientes é semelhante entre todas as unidades, indicando bom nível de satisfação geral. Portanto, a decisão não pode ser fundamentada em problemas de experiência do cliente.
#
# O custo médio de frete da Loja 4 é, inclusive, o menor entre as lojas, demonstrando eficiência logística. Entretanto, esse fator positivo não é suficiente para compensar o menor desempenho financeiro observado.
#
# Após considerar todas as métricas analisadas — faturamento, categorias, avaliações, produtos e frete — concluo que, comparativamente, a Loja 4 apresenta o menor desempenho geral da rede.
#
# Dessa forma, recomendo que a Loja 4 seja a unidade escolhida para venda, permitindo que o capital obtido seja direcionado para seu novo empreendimento.
